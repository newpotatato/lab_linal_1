# %%
from all_for_prepare import *
from eight_val import *
from pca import *

# %%
sample_data = Matrix(5,4,[
    [5.1, 3.5, 1.4, 0.2],
    [4.9, 3.0, 1.4, 0.2],
    [6.2, 3.4, 5.4, 2.3],
    [5.9, 3.0, 5.1, 1.8],
    [6.7, 3.1, 4.7, 1.5],
])
X_proj_qr, ratio_qr = pca_qr(sample_data, k=2)
print(f"Projected data (n×k): {X_proj_qr}")
print(f"Explained variance ratio: {ratio_qr:.4f}")
fig = plot_pca_projection(X_proj_qr)
# Out:
# Projected data (n×k): -2.507607754987199 0.051322810900509386
#  -2.5593412408261225 -0.11859180693717386
#  2.1310551995386993 -0.25175994671266144
#  1.5869484075332654 -0.2884740780355949
#  1.3489453887413576 0.6075030207849224
# Explained variance ratio: 0.9875
